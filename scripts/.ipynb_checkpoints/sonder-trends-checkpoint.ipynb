# %%
import numpy as np
import pandas as pd
import requests
import yaml
import altair as alt

# %%
url = "https://api.ies.ed.gov/eric/"


def load_data(query):
    
    querystring1 = {"search": query, "format": "json", "fields": "publicationdateyear"}
    response1 = requests.request("GET", url, params=querystring1)
    text1 = yaml.safe_load(response1.text)
    results_max = text1["response"]["numFound"]
    print(results_max)
    
    df = []
    results = 0
    start = 0
    while results < results_max:
        querystring = {"search": query, "format": "json", "rows": 2000, "start": start, "fields": "publicationdateyear"}
        response = requests.request("GET", url, params=querystring)
        text = yaml.safe_load(response.text)
        df_mini = pd.DataFrame(text["response"]["docs"])
        df.append(df_mini)
        # keeping at least 30 results
        results += len(df_mini)
        start += 2000
    
    df = pd.concat(df)
    return df

# %%
df = load_data("psychometrics")
# Out:
# 8880

# %%
df
# Out:
#            id                                              title  \
# 0    EJ027787  The Motion Picture as a Psychological Testing ...
# 1    EJ609113                Putting the Psych in Psychometrics.
# 2    EJ037851             Integration Theory and Attitude Change
# 3    EJ040196  Birth Order, Income, Sex, and School Related A...
# 4    EJ038706  The Dynamics of Structured Personality Tests: ...
# ..        ...                                                ...
# 875  ED566739  Handbook of Response to Intervention: The Scie...
# 876  ED580800  International Psychological Applications Confe...
# 877  ED563377  International Psychological Applications Confe...
# 878  ED537453  Proceedings of the International Conference on...
# 879  ED562107  Proceedings of the International Association f...
#
#                                                 author  \
# 0                                 [Seibert, Warren F.]
# 1                                   [Ludlow, Larry H.]
# 2                                [Anderson, Norman H.]
# 3                                 [McClure, Robert F.]
# 4                                [Jackson, Douglas N.]
# ..                                                 ...
# 875  [Jimerson, Shane R., Ed., Burns, Matthew K., E...
# 876          [Pracana, Clara, Ed., Wang, Michael, Ed.]
# 877                              [Pracana, Clara, Ed.]
# 878  [Pechenizkiy, Mykola, Calders, Toon, Conati, C...
# 879  [Sampson, Demetrios G., Ed., Spector, J. Micha...
#
#                                            description  \
# 0
# 1    Describes determining student responses to tea...
# 2
# 3
# 4
# ..                                                 ...
# 875  The second edition of this essential handbook ...
# 876  We are delighted to welcome you to the Interna...
# 877  We are delighted to welcome you to the Interna...
# 878  The 4th International Conference on Educationa...
# 879  These proceedings contain the papers of the IA...
#
#                                                subject  \
# 0        [Films, Psychological Testing, Psychometrics]
# 1    [College Students, Freehand Drawing, Higher Ed...
# 2    [Attitude Change, Information Theory, Informat...
# 3      [Birth Order, Psychometrics, Student Attitudes]
# 4    [Item Analysis, Personality Measures, Psychome...
# ..                                                 ...
# 875  [Response to Intervention, Student Evaluation,...
# 876  [Conferences (Gatherings), Educational Psychol...
# 877  [Educational Psychology, Foreign Countries, In...
# 878  [Academic Achievement, Logical Thinking, Profi...
# 879  [Conference Papers, Cognitive Processes, Learn...
#
#                                publicationtype  publicationdateyear  \
# 0                                           []               1970.0
# 1    [Journal Articles, Reports - Descriptive]               1999.0
# 2                                           []               1971.0
# 3                                           []               1971.0
# 4                                           []               1971.0
# ..                                         ...                  ...
# 875            [Books, Guides - Non-Classroom]               2016.0
# 876            [Collected Works - Proceedings]               2016.0
# 877            [Collected Works - Proceedings]               2014.0
# 878            [Collected Works - Proceedings]               2011.0
# 879            [Collected Works - Proceedings]               2013.0
#
#       language      issn                                          publisher  \
# 0           []        []
# 1    [English]        []
# 2           []        []
# 3           []        []
# 4           []        []
# ..         ...       ...                                                ...
# 875  [English]        []  Springer. 233 Spring Street, New York, NY 1001...
# 876  [English]  [EISSN-]
# 877  [English]        []
# 878  [English]        []  International Working Group on Educational Dat...
# 879  [English]        []  International Association for the Development ...
#
#                          isbn peerreviewed
# 0                          []            F
# 1                          []            T
# 2                          []            T
# 3                          []            T
# 4                          []            T
# ..                        ...          ...
# 875       [978-1-4899-7567-6]            F
# 876       [978-9-8999-3896-0]            T
# 877       [978-9-8997-8666-0]            F
# 878  [ISBN-978-9-0386-2537-9]            F
# 879       [978-989-8533-18-0]            F
#
# [8880 rows x 12 columns]

# %%
#df["publicationdateyear"].value_counts()
df = df["publicationdateyear"].value_counts().rename_axis('year').reset_index(name='counts')

# %%
alt.Chart(df_summ).mark_area().encode(
    x="year:Q",
    y="counts:Q",
    tooltip=["counts"]
)
